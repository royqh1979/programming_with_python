# %%
import numpy as np
import pandas as pd

df = pd.read_csv("学生成绩.csv",encoding="GBK")

# %% [markdown]
# ### 查看内容

# %%
df
# Out:
#            学号    姓名    班级 性别  出生年份   籍贯  数学   语文   英语
# 0   166241101   童绮琴  信管19  男  2001   天津  99   71   65
# 1   166241102   酆友容  信管20  女  2002   广西  81   64   52
# 2   166241103  端木孤菱  信管21  男  2002   湖南  67   90   98
# 3   166241104   闳芳苓  信管22  女  2002   湖北  89  100   90
# 4   166241105   温靖易  信管23  女  2002   吉林  80   70   77
# 5   166241106   祖海亦  信管24  女  2002   天津  72   91   65
# 6   166241107   考依玉  信管25  男  2002   西藏  73   83   66
# 7   166241108   娄昊英  信管26  女  2001   湖南  84   85   59
# 8   166241109   剧星星  信管27  男  2002   北京  66   87   64
# 9   166241110  呼延寻桃  信管28  女  2001   海南  78   65   92
# 10  166241111   天忻然  信管29  女  2001   海南  89   50   98
# 11  166241112   校惜文  信管30  女  2002   吉林  77   64   56
# 12  166241113   汲慧颖  信管31  女  2001   云南  73   85   76
# 13  166241114  东郭勇捷  信管32  男  2001   安徽  85   59   73
# 14  166241115   声恨之  信管33  女  2002   重庆  41   60   60
# 15  166241116   皮谷之  信管34  女  2001  黑龙江  68   68   93
# ...

# %% [markdown]
# ### 查看前n行内容

# %%
df.head()
# Out:
#           学号    姓名    班级 性别  出生年份  籍贯  数学   语文  英语
# 0  166241101   童绮琴  信管19  男  2001  天津  99   71  65
# 1  166241102   酆友容  信管20  女  2002  广西  81   64  52
# 2  166241103  端木孤菱  信管21  男  2002  湖南  67   90  98
# 3  166241104   闳芳苓  信管22  女  2002  湖北  89  100  90
# 4  166241105   温靖易  信管23  女  2002  吉林  80   70  77

# %% [markdown]
# ### 查看末尾n行内容

# %%
df.tail()
# Out:
#            学号   姓名    班级 性别  出生年份  籍贯  数学  语文  英语
# 52  166241224  戈含之  电商41  男  2001  西藏  64  56  64
# 53  166241225  郑月华  电商42  男  2002  北京  95  56  96
# 54  166241226  乾冬卉  电商43  女  2001  甘肃  91  60  62
# 55  166241227  甫念真  电商44  男  2002  广东  88  66  65
# 56  166241228  潘淑婉  电商45  男  2002  福建  79  81  98

# %%
df.columns
# Out:
# Index(['学号', '姓名', '班级', '性别', '出生年份', '籍贯', '数学', '语文', '英语'], dtype='object')

# %%
len(df)
# Out:
# 57

# %%
df.index
# Out:
# RangeIndex(start=0, stop=57, step=1)

# %%
df.dtypes
# Out:
# 学号       int64
# 姓名      object
# 班级      object
# 性别      object
# 出生年份     int64
# 籍贯      object
# 数学       int64
# 语文       int64
# 英语       int64
# dtype: object
