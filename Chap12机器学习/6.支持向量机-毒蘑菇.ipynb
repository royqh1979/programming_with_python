# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

#使用中文字体
mpl.rcParams['font.family']=['Microsoft Yahei','sans-serif']
mpl.rcParams['axes.unicode_minus']=False

#使用svg格式，避免图形模糊
# %matplotlib inline
# %config InlineBackend.figure_format="svg"

# %%
import pandas as pd
df=pd.read_csv("mushroom.csv")
df.head()
# Out:
#       edible cap-shape cap-surface cap-color  bruises     odor  \
# 0  poisonous    convex      smooth     brown     True  pungent
# 1     edible    convex      smooth    yellow     True   almond
# 2     edible      bell      smooth     white     True    anise
# 3  poisonous    convex       scaly     white     True  pungent
# 4     edible    convex      smooth      gray    False     none
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0            free        close    narrow      black  ...
# 1            free        close     broad      black  ...
# 2            free        close     broad      brown  ...
# 3            free        close    narrow      brown  ...
# 4            free      crowded     broad      black  ...
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                   smooth                  white                  white
# 1                   smooth                  white                  white
# 2                   smooth                  white                  white
# 3                   smooth                  white                  white
# 4                   smooth                  white                  white
#
#   veil-type veil-color ring-number   ring-type spore-print-color  population  \
# 0   partial      white           1     pendant             black   scattered
# 1   partial      white           1     pendant             brown    numerous
# 2   partial      white           1     pendant             brown    numerous
# 3   partial      white           1     pendant             black   scattered
# 4   partial      white           1  evanescent             brown    abundant
#
#    habitat
# 0    urban
# 1  grasses
# 2  meadows
# 3    urban
# 4  grasses
#
# [5 rows x 23 columns]

# %%
x=pd.get_dummies(df[df.columns[1:]])
x
# Out:
#       bruises  ring-number  cap-shape_bell  cap-shape_conical  \
# 0        True            1           False              False
# 1        True            1           False              False
# 2        True            1            True              False
# 3        True            1           False              False
# 4       False            1           False              False
# ...       ...          ...             ...                ...
# 8119    False            1           False              False
# 8120    False            1           False              False
# 8121    False            1           False              False
# 8122    False            1           False              False
# 8123    False            1           False              False
#
#       cap-shape_convex  cap-shape_flat  cap-shape_knobbed  cap-shape_sunken  \
# 0                 True           False              False             False
# 1                 True           False              False             False
# 2                False           False              False             False
# 3                 True           False              False             False
# 4                 True           False              False             False
# ...                ...             ...                ...               ...
# 8119             False           False               True             False
# 8120              True           False              False             False
# 8121             False            True              False             False
# 8122             False           False               True             False
# 8123              True           False              False             False
#
#       cap-surface_fibrous  cap-surface_grooves  ...  population_scattered  \
# 0                   False                False  ...                  True
# 1                   False                False  ...                 False
# 2                   False                False  ...                 False
# 3                   False                False  ...                  True
# 4                   False                False  ...                 False
# ...                   ...                  ...  ...                   ...
# 8119                False                False  ...                 False
# 8120                False                False  ...                 False
# 8121                False                False  ...                 False
# 8122                False                False  ...                 False
# 8123                False                False  ...                 False
#
#       population_several  population_solitary  habitat_grasses  \
# 0                  False                False            False
# 1                  False                False             True
# 2                  False                False            False
# 3                  False                False            False
# 4                  False                False             True
# ...                  ...                  ...              ...
# 8119               False                False            False
# 8120                True                False            False
# 8121               False                False            False
# 8122                True                False            False
# 8123               False                False            False
#
#       habitat_leaves  habitat_meadows  habitat_paths  habitat_urban  \
# 0              False            False          False           True
# 1              False            False          False          False
# 2              False             True          False          False
# 3              False            False          False           True
# 4              False            False          False          False
# ...              ...              ...            ...            ...
# 8119            True            False          False          False
# 8120            True            False          False          False
# 8121            True            False          False          False
# 8122            True            False          False          False
# 8123            True            False          False          False
#
#       habitat_waste  habitat_woods
# 0             False          False
# 1             False          False
# 2             False          False
# 3             False          False
# 4             False          False
# ...             ...            ...
# 8119          False          False
# 8120          False          False
# 8121          False          False
# 8122          False          False
# 8123          False          False
#
# [8124 rows x 113 columns]

# %%
y=(df["edible"]=="poisonous")
y
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8119    False
# 8120    False
# 8121    False
# 8122     True
# 8123    False
# Name: edible, Length: 8124, dtype: bool

# %%
#将数据分为训练集和验证集
from sklearn.model_selection import train_test_split

train_x,val_x,train_y,val_y=train_test_split(
    x,y,train_size=0.7)

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear', class_weight='balanced')
model = svc.fit(train_x,train_y)

# %%
from sklearn.metrics import classification_report
yfit = model.predict(val_x)
print(classification_report(val_y, yfit))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1260
#         True       1.00      1.00      1.00      1178
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
